# %%
import pandas as pd

# %%
class Sales_Application():
    """Creating an application for Pyladies Confectionaries"""
    def __init__(self,df,name,index,num_kg):
        """Initializing the df, name, index and num_kg attributes"""
        self.df = df
        self.name = name
        self.index = index
        self.num_kg = num_kg
        
    def inventory(self):
        """Creating a food menu list"""
        return df
    
    def new_features(self):
        """Adding more items to the food menu list"""
        return dff
    
    def user_purchase(self):
        """Computation of a user's purchase of food"""
        return (new_df['Prices(N)'].iloc[int(index)]) * int(number_kg)
    
    def deduct_VAT(self):
        """Deducting 5% VAT on all purchass above 500"""
        if purchase_price > 500:
            return purchase_price + purchase_price * 5 /100
        else:
            return purchase_price
    
    def give_discount(self):
        """Giving a discount of 20% on all purchases above 1000"""
        if purchase_price > 1000:
            return purchase_price - purchase_price * 20 /100
        else:
            return purchase_price
        
Data = [['Jollof Rice', 300, 100],['Fried Rice',400 ,80],
            ['Beans',200 ,65],['Spaghetti', 350, 70],['White Rice',250, 50]]
df = pd.DataFrame(Data,columns=['Food Menu','Prices(N)','Quantity'])
App = Sales_Application(df,"Oluwabunmi",5,3)
IVT = App.inventory()
print("You are welcome to Pyladies Confectionaries! We hope to offer you the best\n")
print("Below is our food menu list,please check it out\n")
print(IVT)


new_row = [['Ramyeon', 1500, 40],['Rice Balls', 600, 50],['Chinese Beans', 1050, 30]]
dff = pd.DataFrame(new_row,columns=['Food Menu','Prices(N)','Quantity'])
New = App.new_features()
new_df = IVT.append(New,ignore_index=True)
print("\nWe have newer and foreign delicacies on our menu now,please take a look at them\n")
print(new_df)


print("\nThese are the available foods we have: \n")
print(new_df['Food Menu'])


index = 5
number_kg = 3
name = "Oluwabunmi Adetunji"
purchase_price = App.user_purchase()
print("\nThe item purchased is {}".format(new_df['Food Menu'].iloc[int(index)]))
print("The price of food purchased is {}\n".format(purchase_price))



print("               Receipt of Purchase from Pyladies Confectionaries            ")
print("Name of User: {}".format(name))
print("Food Purchased: {}".format(new_df['Food Menu'].iloc[int(index)]))
print("Number of kg purchased is {}".format(number_kg))
print("Price of food purchased: {}".format(purchase_price))
print("Date Purchased: 16/07/2020\n")
print("\n                                                               Name of Attendant: Ruth")


Amount_paid = App.deduct_VAT()
print("\nA 5% VAT has been deducted from your account because the item you purchased is above N500 hence you are charged with an amount of {}".format(Amount_paid)) 


Amount = App.give_discount()     
print("\nCongratulations {}!!You've won a discount of 20% on the item you just purchased".format(name))
print("You are only charged with a token of {}".format(Amount))
# Out:
# You are welcome to Pyladies Confectionaries! We hope to offer you the best
#
# Below is our food menu list,please check it out
#
#      Food Menu  Prices(N)  Quantity
# 0  Jollof Rice        300       100
# 1   Fried Rice        400        80
# 2        Beans        200        65
# 3    Spaghetti        350        70
# 4   White Rice        250        50
#
# We have newer and foreign delicacies on our menu now,please take a look at them
#
#        Food Menu  Prices(N)  Quantity
# 0    Jollof Rice        300       100
# 1     Fried Rice        400        80
# 2          Beans        200        65
# 3      Spaghetti        350        70
# 4     White Rice        250        50
# 5        Ramyeon       1500        40
# 6     Rice Balls        600        50
# 7  Chinese Beans       1050        30
#
# These are the available foods we have:
#
# 0      Jollof Rice
# 1       Fried Rice
# 2            Beans
# 3        Spaghetti
# 4       White Rice
# 5          Ramyeon
# 6       Rice Balls
# 7    Chinese Beans
# Name: Food Menu, dtype: object
#
# The item purchased is Ramyeon
# The price of food purchased is 4500
#
#                Receipt of Purchase from Pyladies Confectionaries
# Name of User: Oluwabunmi Adetunji
# Food Purchased: Ramyeon
# Number of kg purchased is 3
# Price of food purchased: 4500
# Date Purchased: 16/07/2020
#
#
#                                                                Name of Attendant: Ruth
#
# A 5% VAT has been deducted from your account because the item you purchased is above N500 hence you are charged with an amount of 4725.0
#
# Congratulations Oluwabunmi Adetunji!!You've won a discount of 20% on the item you just purchased
# You are only charged with a token of 3600.0
